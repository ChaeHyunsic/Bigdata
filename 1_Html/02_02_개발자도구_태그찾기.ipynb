# %% [markdown]
# # 4. 개발자 도구(F12)를 이용해서 원하는 태그 찾기
#
# ![naver금융](../images/naver_금융.png)

# %% [markdown]
# ## 국내증시: 네이버금융

# %% [markdown]
# ![F12](../images/F12개발자도구_1.png)
#
# ![F12](../images/F12개발자도구_2.png)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html=urlopen('https://finance.naver.com/sise/')
soup=BeautifulSoup(html,'html.parser')
print(soup.prettify())
# Out:
# <script language="javascript">
#  function main_tab(tab_title, pst, tab_cnt)
# {
# 	for(var i=0 ; i<tab_cnt ; i++)
# 	{
# 		if (i == pst)
# 			document.getElementById(tab_title+'_title_tab_'+i).style.display = '';
# 		else
# 			document.getElementById(tab_title+'_title_tab_'+i).style.display = 'none';
#
#
# 		if (i == pst)
# 			document.getElementById(tab_title+'_tab_'+i).style.display = '';
# 		else
# 			document.getElementById(tab_title+'_tab_'+i).style.display = 'none';
#
# 	}
# }
#
# function moveIndex(choiceTab) {
# 	jindo.$Element(jindo.$$.getSingle("div.lft > ul")).removeClass("tab tab_sel1");
# 	jindo.$Element(jindo.$$.getSingle("div.lft > ul")).removeClass("tab tab_sel2");
# 	jindo.$Element(jindo.$$.getSingle("div.lft > ul")).removeClass("tab tab_sel3");
# 	jindo.$Element(jindo.$$.getSingle("div.lft > ul")).addClass("tab " + choiceTab);
#
# 	jindo.$ElementList(jindo.$$(".lft#context")).css("display", "none");
# ...

# %%
soup.find_all('span', id='KOSDAQ_now')[0].string
# Out:
# '752.02'

# %% [markdown]
# # 5 실습
#
# ## 5.1 Naver 영화 랭킹

# %% [markdown]
# ![naver_영화랭킹](../images/naver_영화랭킹.png)

# %%
import urllib.request as kk
from bs4 import BeautifulSoup

# %%
html=kk.urlopen('http://movie.naver.com/movie/sdb/rank/rmovie.nhn')
soup=BeautifulSoup(html,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
#    <meta content="네이버영화 " property="me2:post_tag">
#     <meta content="네이버영화" property="me2:category1"/>
#     <meta content="" property="me2:category2"/>
#     <meta content="랭킹 : 네이버 영화" property="og:title"/>
#     <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
#     <meta content="article" property="og:type"/>
#     <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver" property="og:url"/>
#     <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/>
#     <!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
#     <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %% [markdown]
# ### 개발자 보기
#
# ![browser_소스보기](../images/F12개발자도구_5.png)

# %%
tags=soup.findAll('div',attrs={'class':'tit3'})
len(tags)
# Out:
# 50

# %% [markdown]
# ### 검색된 div 태그 내부에서 제목 링크만 추출

# %%
for tag in tags:
    print(tag.a)
# Out:
# <a href="/movie/bi/mi/basic.naver?code=201641" title="공조2: 인터내셔날">공조2: 인터내셔날</a>
# <a href="/movie/bi/mi/basic.naver?code=211161" title="늑대사냥">늑대사냥</a>
# <a href="/movie/bi/mi/basic.naver?code=204640" title="육사오(6/45)">육사오(6/45)</a>
# <a href="/movie/bi/mi/basic.naver?code=195758" title="헌트">헌트</a>
# <a href="/movie/bi/mi/basic.naver?code=194196" title="한산: 용의 출현">한산: 용의 출현</a>
# <a href="/movie/bi/mi/basic.naver?code=81888" title="탑건: 매버릭">탑건: 매버릭</a>
# <a href="/movie/bi/mi/basic.naver?code=202465" title="블랙폰">블랙폰</a>
# <a href="/movie/bi/mi/basic.naver?code=62266" title="아바타">아바타</a>
# <a href="/movie/bi/mi/basic.naver?code=187821" title="인생은 아름다워">인생은 아름다워</a>
# <a href="/movie/bi/mi/basic.naver?code=193324" title="리미트">리미트</a>
# <a href="/movie/bi/mi/basic.naver?code=184519" title="비상선언">비상선언</a>
# <a href="/movie/bi/mi/basic.naver?code=213364" title="인생은 뷰티풀: 비타돌체">인생은 뷰티풀: 비타돌체</a>
# <a href="/movie/bi/mi/basic.naver?code=218812" title="오! 마이 고스트">오! 마이 고스트</a>
# ...

# %%
for tag in tags:
    print(tag.a.text)
# Out:
# 공조2: 인터내셔날
# 늑대사냥
# 육사오(6/45)
# 헌트
# 한산: 용의 출현
# 탑건: 매버릭
# 블랙폰
# 아바타
# 인생은 아름다워
# 리미트
# 비상선언
# 인생은 뷰티풀: 비타돌체
# 오! 마이 고스트
# 드래곤볼 슈퍼: 슈퍼 히어로
# 비스트
# 알라딘
# 정직한 후보2
# 스파이더맨: 노 웨이 홈 '펀버전'
# 9명의 번역가
# 둠둠
# 토르: 러브 앤 썬더
# 폴: 600미터
# 극장판 엄마 까투리: 도시로 간 까투리 가족
# 파로호
# 홈리스
# 놉
# 리멤버
# 애프터: 에버 해피
# 귀멸의 칼날: 장구저택 편
# 외계+인 1부
# 카고
# 아바타 리마스터링
# 토이 스토리 3
# 굿나잇 마미
# 헤어질 결심
# 아이의 노랫소리를 들려줘
# 더 컨트랙터
# 당신의 이웃은 친절하지 않다
# 젊은 남자
# 신비한 동물들과 덤블도어의 비밀
# 노스맨
# 범죄도시2
# 프린세스 아야
# 일상의 관계
# 수퍼 소닉2
# 마녀(魔女) Part2. The Other One
# 어쩌다 공주, 닭냥이 왕자를 부탁해!
# 스마일
# 모비우스
# 컴백홈

# %%
for tag in tags:
    print(tag.a.get_text())
# Out:
# 공조2: 인터내셔날
# 늑대사냥
# 육사오(6/45)
# 헌트
# 한산: 용의 출현
# 탑건: 매버릭
# 블랙폰
# 아바타
# 인생은 아름다워
# 리미트
# 비상선언
# 인생은 뷰티풀: 비타돌체
# 오! 마이 고스트
# 드래곤볼 슈퍼: 슈퍼 히어로
# 비스트
# 알라딘
# 정직한 후보2
# 스파이더맨: 노 웨이 홈 '펀버전'
# 9명의 번역가
# 둠둠
# 토르: 러브 앤 썬더
# 폴: 600미터
# 극장판 엄마 까투리: 도시로 간 까투리 가족
# 파로호
# 홈리스
# 놉
# 리멤버
# 애프터: 에버 해피
# 귀멸의 칼날: 장구저택 편
# 외계+인 1부
# 카고
# 아바타 리마스터링
# 토이 스토리 3
# 굿나잇 마미
# 헤어질 결심
# 아이의 노랫소리를 들려줘
# 더 컨트랙터
# 당신의 이웃은 친절하지 않다
# 젊은 남자
# 신비한 동물들과 덤블도어의 비밀
# 노스맨
# 범죄도시2
# 프린세스 아야
# 일상의 관계
# 수퍼 소닉2
# 마녀(魔女) Part2. The Other One
# 어쩌다 공주, 닭냥이 왕자를 부탁해!
# 스마일
# 모비우스
# 컴백홈

# %% [markdown]
# ### 영화 평점 변화 확인
# - https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20190522

# %%
from bs4 import BeautifulSoup  
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "http://movie.naver.com/"
url_syb = "movie/sdb/rank/rmovie.nhn?sel=cur&date=20190522"

movie_page = urlopen(url_base+url_syb)

soup = BeautifulSoup(movie_page, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
#    <meta content="네이버영화 " property="me2:post_tag">
#     <meta content="네이버영화" property="me2:category1"/>
#     <meta content="" property="me2:category2"/>
#     <meta content="랭킹 : 네이버 영화" property="og:title"/>
#     <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
#     <meta content="article" property="og:type"/>
#     <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20190522" property="og:url"/>
#     <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/>
#     <!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# ...

# %% [markdown]
# ![F12](../images/F12개발자도구_6.png)

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=171539" title="그린 북">그린 북</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=183132" title="교회오빠">교회오빠</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=174830" title="가버나움">가버나움</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=157243" title="당갈">당갈</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=136900" title="어벤져스: 엔드게임">어벤져스: 엔드게임</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=165022" title="호텔 뭄바이">호텔 뭄바이</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=39636" title="지금, 만나러 갑니다">지금, 만나러 갑니다</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=183136" title="뽀로로 극장판 보물섬 대모험">뽀로로 극장판 보물섬 대모험</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=182348" title="로망">로망</a>
#  </div>,
# ...

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '그린 북'

# %%
soup.find_all('td', 'point')
# Out:
# [<td class="point">9.62</td>,
#  <td class="point">9.61</td>,
#  <td class="point">9.60</td>,
#  <td class="point">9.43</td>,
#  <td class="point">9.39</td>,
#  <td class="point">9.37</td>,
#  <td class="point">9.34</td>,
#  <td class="point">9.29</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.21</td>,
#  <td class="point">9.12</td>,
#  <td class="point">9.07</td>,
#  <td class="point">9.07</td>,
#  <td class="point">9.04</td>,
#  <td class="point">9.04</td>,
#  <td class="point">8.94</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.87</td>,
#  <td class="point">8.75</td>,
#  <td class="point">8.60</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.49</td>,
#  <td class="point">8.32</td>,
#  <td class="point">8.29</td>,
#  <td class="point">8.28</td>,
#  <td class="point">8.24</td>,
#  <td class="point">8.21</td>,
#  <td class="point">8.20</td>,
#  <td class="point">8.13</td>,
#  <td class="point">8.06</td>,
# ...

# %% [markdown]
# #### 주어진 날짜에 해당되는 영화 정보 전체 찾기

# %%
date = pd.date_range('2018-5-1', periods=50, freq='W')
print(len(date))
date
# Out:
# 50
# DatetimeIndex(['2018-05-06', '2018-05-13', '2018-05-20', '2018-05-27',
#                '2018-06-03', '2018-06-10', '2018-06-17', '2018-06-24',
#                '2018-07-01', '2018-07-08', '2018-07-15', '2018-07-22',
#                '2018-07-29', '2018-08-05', '2018-08-12', '2018-08-19',
#                '2018-08-26', '2018-09-02', '2018-09-09', '2018-09-16',
#                '2018-09-23', '2018-09-30', '2018-10-07', '2018-10-14',
#                '2018-10-21', '2018-10-28', '2018-11-04', '2018-11-11',
#                '2018-11-18', '2018-11-25', '2018-12-02', '2018-12-09',
#                '2018-12-16', '2018-12-23', '2018-12-30', '2019-01-06',
#                '2019-01-13', '2019-01-20', '2019-01-27', '2019-02-03',
#                '2019-02-10', '2019-02-17', '2019-02-24', '2019-03-03',
#                '2019-03-10', '2019-03-17', '2019-03-24', '2019-03-31',
#                '2019-04-07', '2019-04-14'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# C:\Users\Uou\AppData\Local\Temp\ipykernel_21620\1859345539.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for today in tqdm_notebook(date):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (2136, 2136, 2136)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date         name point
# 0 2018-05-06           당갈  9.59
# 1 2018-05-06           덕구  9.50
# 2 2018-05-06           원더  9.40
# 3 2018-05-06       위대한 쇼맨  9.38
# 4 2018-05-06  지금, 만나러 갑니다  9.33

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2136 entries, 0 to 2135
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2136 non-null   datetime64[ns]
#  1   name    2136 non-null   object
#  2   point   2136 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 50.2+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#            point
# name
# 소공녀       302.03
# 어느 가족     249.25
# 러빙 빈센트    230.07
# 보헤미안 랩소디  227.89
# 스타 이즈 본   210.73

# %%
tmp = movie.query('name == ["벤허"]')
tmp
# Out:
#            date name  point
# 449  2018-07-22   벤허   9.22
# 498  2018-07-29   벤허   9.22
# 884  2018-09-23   벤허   9.22
# 1996 2019-03-31   벤허   9.20
# 2046 2019-04-07   벤허   9.21
# 2093 2019-04-14   벤허   9.20

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 5.2 ID 추출
#
# - http://goo.gl/U7mSQl
#
# ![이벤트당첨자](../images/그림14-9_p488.png)
#
# - ID pattern: [A-Za-z0-9]+\*\*\*

# %%
import re
import urllib.request

url = "http://goo.gl/U7mSQl"             # 접속할 페이지
html = urllib.request.urlopen(url)       # 페이지 열기
html_contents = str(html.read())         # 페이지의 내용을 문자열로 가져옴
id_results = re.findall(r"([A-Za-z0-9]+\*\*\*)", html_contents)
# findall 전체 찾기, 정규 표현식 패턴 대로 데이터 찾기

for result in id_results:                 # 찾은 정보를 화면에 출력
    print (result)
# Out:
# codo***
# outb7***
# dubba4***
# multicuspi***
# crownm***
# triformo***
# spania***
# magazin***
# presby***
# trophody***
# nontr***
# enranck***
# canc***
# uncanker***
# wrymo***
# non***
# luminat***
# oblig***
# anna***
# hyperth***
# toplabl***
# dolce0***
# rudals2***
# jjw980***
# elvlz***
# skmid***
# qkep***
# kisslov***
# maskman***
# sungt***

# %% [markdown]
# ## 5.3 삼성전자 주식
# - <dl class="blind"\> ..... </dl\> 부분에서
# - <dd\> .... </dd\>  정보 추출

# %%
import urllib.request
import re

url ="http://finance.naver.com/item/main.nhn?code=005930"
html = urllib.request.urlopen(url)
html_contents =str(html.read().decode("ms949"))

# 첫 번째 HTML 패턴
stock_results = re.findall("(\<dl class=\"blind\"\>)([\s\S]+?)(\<\/dl\>)", html_contents)
samsung_stock = stock_results[0]     # 첫번째 <dl class="blind"> ..... </dl> 
samsung_index = samsung_stock[1]     # <dd> .... </dd> 

# 주식 정보만 추출함
index_list= re.findall("(\<dd\>)([\s\S]+?)(\<\/dd\>)", samsung_index)

for index in index_list:
    print(index[1])                # 세 개의 튜플 값 중 두 번째 값
# Out:
# 2022년 09월 21일 15시 20분 기준 장중
# 종목명 삼성전자
# 종목코드 005930 코스피
# 현재가 55,300 전일대비 하락 500 마이너스 0.90 퍼센트
# 전일가 55,800
# 시가 55,400
# 고가 55,500
# 상한가 72,500
# 저가 55,000
# 하한가 39,100
# 거래량 10,543,734
# 거래대금 582,030백만

# %%
stock_results
# Out:
# [('<dl class="blind">',
#   '\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2022년 09월 21일 15시 20분 기준 장중</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 55,300 전일대비 하락 500 마이너스 0.90 퍼센트</dd>\n\t        <dd>전일가 55,800</dd>\n\t        <dd>시가 55,400</dd>\n\t        <dd>고가 55,500</dd>\n\t        <dd>상한가 72,500</dd>\n\t        <dd>저가 55,000</dd>\n\t        <dd>하한가 39,100</dd>\n\t        <dd>거래량 10,543,734</dd>\n\t        <dd>거래대금 582,030백만</dd>\n        ',
#   '</dl>'),
#  ('<dl class="blind">',
#   '\n                        <dt><strong>삼성전자</strong></dt>\n                        <dd>오늘의시세 55,300 포인트</dd>\n                        <dd>500 포인트 하락</dd>\n                        <dd>0.90% 마이너스</dd>\n                ',
#   '</dl>')]

# %%
samsung_stock
# Out:
# ('<dl class="blind">',
#  '\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2022년 09월 21일 15시 20분 기준 장중</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 55,300 전일대비 하락 500 마이너스 0.90 퍼센트</dd>\n\t        <dd>전일가 55,800</dd>\n\t        <dd>시가 55,400</dd>\n\t        <dd>고가 55,500</dd>\n\t        <dd>상한가 72,500</dd>\n\t        <dd>저가 55,000</dd>\n\t        <dd>하한가 39,100</dd>\n\t        <dd>거래량 10,543,734</dd>\n\t        <dd>거래대금 582,030백만</dd>\n        ',
#  '</dl>')

# %%
samsung_index
# Out:
# '\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2022년 09월 21일 15시 20분 기준 장중</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 55,300 전일대비 하락 500 마이너스 0.90 퍼센트</dd>\n\t        <dd>전일가 55,800</dd>\n\t        <dd>시가 55,400</dd>\n\t        <dd>고가 55,500</dd>\n\t        <dd>상한가 72,500</dd>\n\t        <dd>저가 55,000</dd>\n\t        <dd>하한가 39,100</dd>\n\t        <dd>거래량 10,543,734</dd>\n\t        <dd>거래대금 582,030백만</dd>\n        '
